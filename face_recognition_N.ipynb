# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 4.2 MB/s eta 0:00:10
#    -- ------------------------------------- 2.1/39.5 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.4/39.5 MB 5.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.7/39.5 MB 5.8 MB/s eta 0:00:06
#    ------ --------------------------------- 6.0/39.5 MB 5.8 MB/s eta 0:00:06
#    ------- -------------------------------- 7.1/39.5 MB 5.8 MB/s eta 0:00:06
#    -------- ------------------------------- 8.1/39.5 MB 5.8 MB/s eta 0:00:06
#    --------- ------------------------------ 9.4/39.5 MB 5.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.5/39.5 MB 5.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.8/39.5 MB 5.8 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/39.5 MB 5.7 MB/s eta 0:00:05
# ...

# %%
import cv2
import urllib.request
print(cv2.__version__)
# Out:
# 4.11.0

# %%
url = 'https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml'
urllib.request.urlretrieve(url, 'haarcascade_frontalface_default.xml')

url = 'https://upload.wikimedia.org/wikipedia/commons/b/be/Official_portrait_of_the_Prime_Minister_Narendra_Modi%2C_November_2020_%28cropped%29.jpg'
urllib.request.urlretrieve(url, 'mod.jpg')

url = 'https://peepingmoon-cdn.sgp1.digitaloceanspaces.com/engpeepingmoon/wp-content/uploads/2018/10/dmckdsmn.jpg'
urllib.request.urlretrieve(url, '2.jpg')

url = 'https://currentaffairs.adda247.com/wp-content/uploads/multisite/sites/5/2024/03/16160211/Top-10-Famous-Indian-Cricketers.png'
urllib.request.urlretrieve(url, '3.png')

url = 'https://www.soulflower.in/cdn/shop/articles/Skincare_472906b3-2b78-46d9-8897-40c2ac645181.png?v=1741589333&width=1100'
urllib.request.urlretrieve(url, 'hers.png')

url = 'https://cdn.cfr.org/sites/default/files/image/2022/08/RTR2LVWP.jpg'
urllib.request.urlretrieve(url, 'ter.jpg')
# Out:
# ('ter.jpg', <http.client.HTTPMessage at 0x22e5d44c3e0>)

# %% [markdown]
# Download face Datasets : https://raw.githubusercontent.com/Projects-Developer/Face-Detection-Project/main/haarcascade_frontalface_default.xml

# %%
classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_image = cv2.imread('mod.jpg')
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image_gray, cmap='gray')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
 haar_cascade_face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  1

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(convertToRGB(test_image))

# %%
def detect_faces(cascade, test_image, scaleFactor = 1.1):
    image_copy = test_image.copy()

    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
    
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)

    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

    return image_copy

# %% [markdown]
# **Modi ji with Bollywood Stars**

# %%
test_image = cv2.imread('2.jpg')
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image_gray, cmap='gray')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  6

# %%
faces = detect_faces(haar_cascade_face, test_image)
plt.imshow(convertToRGB(faces))

# %% [markdown]
# ## Indian Cricket

# %%
test_image = cv2.imread('3.png')
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image_gray, cmap='gray')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
haar_cascade_face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  9

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(convertToRGB(test_image))

# %%
test_image = cv2.imread('hers.png')
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image_gray, cmap='gray')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  7

# %%
faces = detect_faces(haar_cascade_face, test_image)
plt.imshow(convertToRGB(faces))

# %% [markdown]
# ####**Terrorist Face Detection**

# %%
test_image = cv2.imread('ter.jpg')
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

plt.imshow(test_image_gray, cmap='gray')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  2

# %%
faces = detect_faces(haar_cascade_face, test_image)
plt.imshow(convertToRGB(faces))

# %% [markdown]
# LIVE WEBCAM FACE DETECTION !

# %%
import cv2

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

while True:
    _, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    cv2.imshow('img', img)
    k = cv2.waitKey(30) & 0xff
    if k==27:
        break
cap.release()

# %%
import numpy as np
import cv2
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)
cap.set(3,640) 
cap.set(4,480) 
while True:
    ret, img = cap.read()
    img = cv2.flip(img, -1)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(20, 20)
    )
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
    cv2.imshow('video',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
